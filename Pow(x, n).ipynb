# %%
class Solution(object):
    def myPow(x, n):
        return x ** n

# %%
x = 2.00000
n = 5

# %%
Solution.myPow(x,n)
# Out:
# 32.0
# Bad pipe message: %s [b'\x1b\x92Mt\xf1\x1a\xc64b\xfb\x077\xce\x1f\xe7td\x83 Z\xde\x1ck\xb4\xa8_>\xa4(\xf56\xf9\x81Ye\xe1\x1b\xbf^}\xf5\xe7P\x8f-%b\xe3\xf3\xb9H\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04']
# ...

# %%
x = 2.10000
n = 3

# %%
Solution.myPow(x,n)
# Out:
# 9.261000000000001

# %%
x = 2.00000
n = -2

# %%
Solution.myPow(x,n)
# Out:
# 0.25
